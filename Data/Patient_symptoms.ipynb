# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("patient_data_50.csv")

# %%
df.disease.unique()
# Out:
# array(['hypertension', 'endometriosis', 'prostate cancer',
#        'multiple sclerosis', 'skin cancer', "Alzheimer's disease",
#        'kidney disease', 'breast cancer', 'HIV/AIDS', 'heart disease',
#        'diabetes', 'gastritis'], dtype=object)

# %%
my_cols = list(range(0,30))
df_diease = pd.read_csv("diseases_and_symptoms.csv", names=my_cols, engine="python")

# %%
df_diease
# Out:
#                                        0   \
# 0                    hypertensive disease
# 1                                diabetes
# 2                       depression mental
# 3               coronary arteriosclerosis
# 4                               pneumonia
# 5                failure heart congestive
# 6                accident cerebrovascular
# 7                                  asthma
# 8                   myocardial infarction
# 9                    hypercholesterolemia
# 10                              infection
# 11                infection urinary tract
# 12                                 anemia
# 13     chronic obstructive airway disease
# 14                               dementia
# 15                    insufficiency renal
# 16                              confusion
# 17             degenerative polyarthritis
# 18                         hypothyroidism
# 19                          anxiety state
# 20                    malignant neoplasms
# ...

# %%
prostate = df_diease[df_diease[0]=="malignant neoplasm of prostate"].values
hypertension = df_diease[df_diease[0]=="hypertensive disease"].values
skincancer = df_diease[df_diease[0]=="malignant neoplasms"].values
alzheimer = df_diease[df_diease[0]=="Alzheimer's disease"].values
kidney = df_diease[df_diease[0]=="kidney disease"].values
breastc = df_diease[df_diease[0]=="malignant neoplasm of breast"].values
aids = df_diease[df_diease[0]=="acquired immuno-deficiency syndrome"].values
hearth = df_diease[df_diease[0]=="myocardial infarction"].values
diabetes = df_diease[df_diease[0]=="diabetes"].values
gastritis = df_diease[df_diease[0]=="gastritis"].values

# %%
print(gastritis[0][1:8])
# Out:
# ['heme positive' 'pain abdominal' 'vomiting' 'disequilibrium' 'nausea'
#  'intoxication' 'haemorrhage']

# %%
my_cols = list(range(0,30))
df_diease = pd.read_csv("diseases_and_symptoms.csv", names=my_cols, engine="python")

# %%
df_diease.sort_values(by=[0])
# Out:
#                                        0                        1   \
# 89                    Alzheimer's disease                    drool
# 82         Pneumocystis carinii pneumonia            yellow sputum
# 6                accident cerebrovascular               dysarthria
# 21    acquired immuno-deficiency syndrome                    fever
# 50                         adenocarcinoma   mass of body structure
# 130                              adhesion               flatulence
# 132                         affect labile       extreme exhaustion
# 12                                 anemia                    chill
# 19                          anxiety state                    worry
# 110                               aphasia                   clonus
# 45                              arthritis                     pain
# 7                                  asthma                 wheezing
# 67                             bacteremia                    fever
# ...

# %%
df2 = pd.read_csv("disease_fachrichtung.csv", encoding="latin2")
df2.sort_values(by="disease")
# Out:
#                                 disease  \
# 5                   Alzheimer's disease
# 8   acquired immuno-deficiency syndrome
# 10                             diabetes
# 1                         endometriosis
# 11                            gastritis
# 9                         heart disease
# 0                  hypertensive disease
# 6                        kidney disease
# 7          malignant neoplasm of breast
# 2        malignant neoplasm of prostate
# 4            malignant neoplasm of skin
# 3                    multiple sclerosis
# 12                        schizophrenia
#
#                                          fachrichtung
# 5                               Neurologe, Neurologin
# 8                         Infektiologe, Infektiologin
# 10  Endokrinologe u. Diabetologe, Endokrinologin u...
# 1                            Frauenarzt, Frauenärztin
# 11                             Internist, Internistin
# 9                             Kardiologe, Kardiologin
# ...

# %%
print(df2[df2["disease"]=="malignant neoplasm of skin"].fachrichtung.unique())
# Out:
# ['Hautarzt, Hautärztin']
